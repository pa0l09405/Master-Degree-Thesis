# %%
#DA ESEGUIRE 1 SOLA VOLTA !!!!
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo2/") 
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
# !nvidia-smi
# Out:
# Sun Nov  8 14:55:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo2/pytorch-CycleGAN-and-pix2pix") 
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.7.0+cu101)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.8.1+cu101)
# Requirement already satisfied: dominate>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (2.6.0)
# Requirement already satisfied: visdom>=0.1.8.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.1.8.9)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.23.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (19.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.26)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (0.57.0)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.6/dist-packages (from jsonpatch->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.0)

# %%
"""


A (source domain), B (target domain).
        Generators: G_A: A -> B; G_B: B -> A.
        Discriminators: D_A: G_A(A) vs. B; D_B: G_B(B) vs. A.
        Forward cycle loss:  lambda_A * ||G_B(G_A(A)) - A|| (Eqn. (2) in the paper)
        Backward cycle loss: lambda_B * ||G_A(G_B(B)) - B|| (Eqn. (2) in the paper)
        Identity loss (optional): lambda_identity * (||G_A(B) - B|| * lambda_B + ||G_B(A) - A|| * lambda_A) (Sec 5.2 "Photo generation from paintings" in the paper)
        Dropout is not used in the original CycleGAN paper.




epoch: -- current epoch

iters: -- current training iteration during this epoch (reset to 0 at the end of every epoch) 

time: -- current training iteration during this epoch (reset to 0 at the end of every epoch)

data: -- data loading time per data point (normalized by batch_size) 

D_A: GAN loss for discriminator D_A
G_A: loss for generators G_A 
cycle_A: cycle-consistency loss A 
idt_A: identity loss B 

D_B: GAN loss for discriminator D_B 
G_B: loss for generators G_B 
cycle_B: cycle-consistency loss B 
idt_B: identity loss B






# #epoche
# #epochs_decay
#dataroot
#input_nc
#output_nc
#norm
#no_dropout 
#dataset_mode
#direction
#batch size (adesso è 1!)
#load_size
#crop_size
#preprocess
# save_latest_freq default 5000
# save_epoch_freq default 5
"""
import os
os.chdir("/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo2/pytorch-CycleGAN-and-pix2pix")
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 13 --lr 0.002
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002


#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 8 --lr 0.002 --checkpoints_dir './checkpoints_normV1'
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002 --checkpoints_dir './checkpoints_normV1'

#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 1 --lr 0.002 --checkpoints_dir './checkpoints_normV2'
#CYCLEGAN 30 X 30
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --preprocess 'none' --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 4 --n_epochs_decay 11 --lr 0.002 --checkpoints_dir './checkpoints_normV2'
#CYCLEGAN 70 X 70
# !python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --batch_size 5 --name DCEMRI_cyclegan --load_size 256 --netD n_layers --n_layers_D 2 --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --netG unet_256 --input_nc 1 --output_nc 1 --n_epochs 10 --n_epochs_decay 30 --lr 0.0002 --checkpoints_dir './checkpoints_normV2_lr_0_0002'
# Out:
# ----------------- Options ---------------
#                batch_size: 5                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints_normV2_lr_0_0002	[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/DCE_MRI_breastCancer_normV2	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 384                           	[default: 256]
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256                           	[default: 286]
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: cycle_gan
#                  n_epochs: 10                            	[default: 100]
#            n_epochs_decay: 30                            	[default: 100]
#                n_layers_D: 2                             	[default: 3]
#                      name: DCEMRI_cyclegan               	[default: experiment_name]
#                       ndf: 64
#                      netD: n_layers                      	[default: basic]
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True
#                   no_flip: True                          	[default: False]
#                   no_html: False
#                      norm: instance
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 1
#          save_latest_freq: 115
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# The number of training images = 2725
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 54.403 M
# [Network G_B] Total number of parameters : 54.403 M
# [Network D_A] Total number of parameters : 0.661 M
# [Network D_B] Total number of parameters : 0.661 M
# -----------------------------------------------
# create web directory ./checkpoints_normV2_lr_0_0002/DCEMRI_cyclegan/web...
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# learning rate 0.0002000 -> 0.0002000
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 115)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 230)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 345)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 460)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 575)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 690)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 805)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 920)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1035)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1150)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1265)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1380)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1495)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1610)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1725)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1840)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 1955)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2070)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2185)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2300)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2415)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2530)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 1, total_iters 2645)
# [epoch : 1 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 1, iters 2725
# End of epoch 1 / 40 	 Time Taken: 1126 sec
# (epoch: 1, iters: 2725, time: 0.081, data: 0.997) D_A: 0.189 G_A: 0.351 cycle_A: 0.130 idt_A: 0.096 D_B: 0.205 G_B: 0.399 cycle_B: 0.273 idt_B: 0.071
# learning rate 0.0002000 -> 0.0002000
# saving the latest model (epoch 2, total_iters 2760)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 2875)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 2990)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3105)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3220)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3335)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3450)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3565)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3680)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3795)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 3910)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4025)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4140)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4255)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4370)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4485)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4600)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4715)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4830)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 4945)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 5060)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 5175)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 5290)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 5405)
# saving the model at the end of epoch 2, iters 5450
# End of epoch 2 / 40 	 Time Taken: 275 sec
# (epoch: 2, iters: 2725, time: 0.099, data: 0.001) D_A: 0.258 G_A: 0.313 cycle_A: 0.130 idt_A: 0.061 D_B: 0.174 G_B: 0.302 cycle_B: 0.215 idt_B: 0.059
# learning rate 0.0002000 -> 0.0002000
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 5520)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 5635)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 5750)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 5865)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 5980)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6095)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6210)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6325)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6440)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6555)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6670)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6785)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 6900)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7015)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7130)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7245)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7360)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7475)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7590)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7705)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7820)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 7935)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 8050)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 8165)
# saving the model at the end of epoch 3, iters 8175
# End of epoch 3 / 40 	 Time Taken: 271 sec
# (epoch: 3, iters: 2725, time: 0.099, data: 0.001) D_A: 0.240 G_A: 0.256 cycle_A: 0.138 idt_A: 0.047 D_B: 0.217 G_B: 0.367 cycle_B: 0.203 idt_B: 0.060
# learning rate 0.0002000 -> 0.0002000
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8280)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8395)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8510)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8625)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8740)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8855)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 8970)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9085)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9200)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9315)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9430)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9545)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9660)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9775)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 9890)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10005)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10120)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10235)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10350)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10465)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10580)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10695)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 4, total_iters 10810)
# [epoch : 4 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 4, iters 10900
# End of epoch 4 / 40 	 Time Taken: 264 sec
# (epoch: 4, iters: 2725, time: 0.099, data: 0.002) D_A: 0.246 G_A: 0.311 cycle_A: 0.076 idt_A: 0.032 D_B: 0.143 G_B: 0.328 cycle_B: 0.143 idt_B: 0.030
# learning rate 0.0002000 -> 0.0002000
# saving the latest model (epoch 5, total_iters 10925)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11040)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11155)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11270)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11385)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11500)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11615)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11730)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11845)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 11960)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12075)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12190)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12305)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12420)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12535)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12650)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12765)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12880)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 12995)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 13110)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 13225)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 13340)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 13455)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 13570)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 5, iters 13625
# End of epoch 5 / 40 	 Time Taken: 267 sec
# (epoch: 5, iters: 2725, time: 0.099, data: 0.002) D_A: 0.240 G_A: 0.332 cycle_A: 0.119 idt_A: 0.026 D_B: 0.193 G_B: 0.433 cycle_B: 0.114 idt_B: 0.047
# learning rate 0.0002000 -> 0.0002000
# saving the latest model (epoch 6, total_iters 13685)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 13800)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 13915)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14030)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14145)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14260)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14375)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14490)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14605)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14720)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14835)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 14950)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15065)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15180)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15295)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15410)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15525)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15640)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15755)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15870)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 15985)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 16100)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 16215)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 16330)
# saving the model at the end of epoch 6, iters 16350
# End of epoch 6 / 40 	 Time Taken: 272 sec
# (epoch: 6, iters: 2725, time: 0.099, data: 0.002) D_A: 0.246 G_A: 0.316 cycle_A: 0.090 idt_A: 0.025 D_B: 0.229 G_B: 0.616 cycle_B: 0.127 idt_B: 0.034
# learning rate 0.0002000 -> 0.0002000
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 16445)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 16560)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 16675)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 16790)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 16905)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17020)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17135)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17250)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17365)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17480)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17595)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17710)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17825)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 17940)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18055)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18170)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18285)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18400)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18515)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18630)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18745)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18860)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 18975)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 7, iters 19075
# End of epoch 7 / 40 	 Time Taken: 266 sec
# (epoch: 7, iters: 2725, time: 0.099, data: 0.002) D_A: 0.234 G_A: 0.248 cycle_A: 0.091 idt_A: 0.024 D_B: 0.233 G_B: 0.325 cycle_B: 0.156 idt_B: 0.032
# learning rate 0.0002000 -> 0.0002000
# saving the latest model (epoch 8, total_iters 19090)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19205)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19320)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19435)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19550)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19665)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19780)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 19895)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20010)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20125)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20240)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20355)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20470)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20585)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20700)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20815)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 20930)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21045)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21160)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21275)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21390)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21505)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21620)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 8, total_iters 21735)
# [epoch : 8 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 8, iters 21800
# End of epoch 8 / 40 	 Time Taken: 269 sec
# (epoch: 8, iters: 2725, time: 0.099, data: 0.002) D_A: 0.215 G_A: 0.217 cycle_A: 0.114 idt_A: 0.020 D_B: 0.250 G_B: 0.301 cycle_B: 0.122 idt_B: 0.032
# learning rate 0.0002000 -> 0.0002000
# saving the latest model (epoch 9, total_iters 21850)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 21965)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22080)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22195)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22310)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22425)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22540)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22655)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22770)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 22885)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23000)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23115)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23230)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23345)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23460)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23575)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23690)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23805)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 23920)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 24035)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 24150)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 24265)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 24380)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 24495)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 9, iters 24525
# End of epoch 9 / 40 	 Time Taken: 270 sec
# (epoch: 9, iters: 2725, time: 0.081, data: 0.002) D_A: 0.237 G_A: 0.334 cycle_A: 0.076 idt_A: 0.016 D_B: 0.210 G_B: 0.271 cycle_B: 0.116 idt_B: 0.027
# learning rate 0.0002000 -> 0.0001935
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 24610)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 24725)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 24840)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 24955)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25070)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25185)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25300)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25415)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25530)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25645)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25760)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25875)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 25990)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26105)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26220)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26335)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26450)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26565)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26680)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26795)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 26910)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 27025)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 27140)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the model at the end of epoch 10, iters 27250
# End of epoch 10 / 40 	 Time Taken: 266 sec
# (epoch: 10, iters: 2725, time: 0.099, data: 0.002) D_A: 0.232 G_A: 0.234 cycle_A: 0.099 idt_A: 0.018 D_B: 0.210 G_B: 0.233 cycle_B: 0.132 idt_B: 0.035
# learning rate 0.0001935 -> 0.0001871
# saving the latest model (epoch 11, total_iters 27255)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27370)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27485)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27600)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27715)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27830)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 27945)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28060)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28175)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28290)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28405)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28520)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28635)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28750)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28865)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 28980)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29095)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29210)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29325)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29440)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29555)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29670)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29785)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 29900)
# saving the model at the end of epoch 11, iters 29975
# End of epoch 11 / 40 	 Time Taken: 270 sec
# (epoch: 11, iters: 2725, time: 0.099, data: 0.002) D_A: 0.265 G_A: 0.274 cycle_A: 0.102 idt_A: 0.022 D_B: 0.179 G_B: 0.429 cycle_B: 0.144 idt_B: 0.038
# learning rate 0.0001871 -> 0.0001806
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30015)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30130)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30245)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30360)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30475)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30590)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30705)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30820)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 30935)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31050)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31165)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31280)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31395)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31510)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31625)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31740)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31855)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 31970)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32085)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32200)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32315)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32430)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32545)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the latest model (epoch 12, total_iters 32660)
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# saving the model at the end of epoch 12, iters 32700
# End of epoch 12 / 40 	 Time Taken: 266 sec
# (epoch: 12, iters: 2725, time: 0.098, data: 0.002) D_A: 0.254 G_A: 0.298 cycle_A: 0.064 idt_A: 0.013 D_B: 0.197 G_B: 0.260 cycle_B: 0.104 idt_B: 0.027
# learning rate 0.0001806 -> 0.0001742
# saving the latest model (epoch 13, total_iters 32775)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 32890)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33005)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33120)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33235)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33350)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33465)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33580)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33695)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33810)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 33925)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34040)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34155)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34270)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34385)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34500)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34615)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34730)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34845)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 34960)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 35075)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 35190)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 35305)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 35420)
# saving the model at the end of epoch 13, iters 35425
# End of epoch 13 / 40 	 Time Taken: 271 sec
# (epoch: 13, iters: 2725, time: 0.098, data: 0.002) D_A: 0.237 G_A: 0.337 cycle_A: 0.062 idt_A: 0.019 D_B: 0.202 G_B: 0.353 cycle_B: 0.173 idt_B: 0.023
# learning rate 0.0001742 -> 0.0001677
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 35535)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 35650)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 35765)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 35880)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 35995)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36110)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36225)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36340)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36455)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36570)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36685)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36800)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 36915)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37030)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37145)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37260)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37375)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37490)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37605)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37720)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37835)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 37950)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 38065)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the model at the end of epoch 14, iters 38150
# End of epoch 14 / 40 	 Time Taken: 266 sec
# (epoch: 14, iters: 2725, time: 0.098, data: 0.002) D_A: 0.238 G_A: 0.295 cycle_A: 0.084 idt_A: 0.012 D_B: 0.193 G_B: 0.432 cycle_B: 0.073 idt_B: 0.037
# learning rate 0.0001677 -> 0.0001613
# saving the latest model (epoch 15, total_iters 38180)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38295)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38410)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38525)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38640)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38755)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38870)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 38985)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39100)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39215)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39330)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39445)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39560)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39675)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39790)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 39905)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40020)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40135)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40250)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40365)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40480)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40595)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40710)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 40825)
# saving the model at the end of epoch 15, iters 40875
# End of epoch 15 / 40 	 Time Taken: 270 sec
# (epoch: 15, iters: 2725, time: 0.098, data: 0.002) D_A: 0.242 G_A: 0.281 cycle_A: 0.070 idt_A: 0.009 D_B: 0.237 G_B: 0.267 cycle_B: 0.087 idt_B: 0.027
# learning rate 0.0001613 -> 0.0001548
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# saving the latest model (epoch 16, total_iters 40940)
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# saving the latest model (epoch 16, total_iters 41055)
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# saving the latest model (epoch 16, total_iters 41170)
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# saving the latest model (epoch 16, total_iters 41285)
# ...
#
# saving the latest model (epoch 35, total_iters 94990)
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# saving the latest model (epoch 35, total_iters 95105)
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# saving the latest model (epoch 35, total_iters 95220)
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# saving the latest model (epoch 35, total_iters 95335)
# saving the model at the end of epoch 35, iters 95375
# End of epoch 35 / 40 	 Time Taken: 273 sec
# (epoch: 35, iters: 2725, time: 0.098, data: 0.002) D_A: 0.223 G_A: 0.314 cycle_A: 0.067 idt_A: 0.008 D_B: 0.230 G_B: 0.241 cycle_B: 0.056 idt_B: 0.019
# learning rate 0.0000323 -> 0.0000258
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 95450)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 95565)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 95680)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 95795)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 95910)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96025)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96140)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96255)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96370)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96485)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96600)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96715)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96830)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 96945)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97060)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97175)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97290)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97405)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97520)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97635)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97750)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97865)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 97980)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 98095)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the model at the end of epoch 36, iters 98100
# End of epoch 36 / 40 	 Time Taken: 275 sec
# (epoch: 36, iters: 2725, time: 0.081, data: 0.002) D_A: 0.244 G_A: 0.279 cycle_A: 0.048 idt_A: 0.008 D_B: 0.249 G_B: 0.226 cycle_B: 0.054 idt_B: 0.013
# learning rate 0.0000258 -> 0.0000194
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98210)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98325)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98440)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98555)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98670)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98785)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 98900)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99015)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99130)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99245)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99360)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99475)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99590)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99705)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99820)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 99935)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100050)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100165)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100280)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100395)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100510)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100625)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 100740)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the model at the end of epoch 37, iters 100825
# End of epoch 37 / 40 	 Time Taken: 267 sec
# (epoch: 37, iters: 2725, time: 0.098, data: 0.002) D_A: 0.250 G_A: 0.288 cycle_A: 0.075 idt_A: 0.008 D_B: 0.248 G_B: 0.233 cycle_B: 0.058 idt_B: 0.021
# learning rate 0.0000194 -> 0.0000129
# saving the latest model (epoch 38, total_iters 100855)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 100970)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101085)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101200)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101315)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101430)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101545)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101660)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101775)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 101890)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102005)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102120)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102235)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102350)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102465)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102580)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102695)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102810)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 102925)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 103040)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 103155)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 103270)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 103385)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 103500)
# saving the model at the end of epoch 38, iters 103550
# End of epoch 38 / 40 	 Time Taken: 270 sec
# (epoch: 38, iters: 2725, time: 0.098, data: 0.002) D_A: 0.236 G_A: 0.272 cycle_A: 0.066 idt_A: 0.008 D_B: 0.251 G_B: 0.263 cycle_B: 0.065 idt_B: 0.019
# learning rate 0.0000129 -> 0.0000065
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 103615)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 103730)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 103845)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 103960)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104075)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104190)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104305)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104420)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104535)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104650)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104765)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104880)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 104995)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105110)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105225)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105340)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105455)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105570)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105685)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105800)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 105915)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 106030)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 106145)
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# saving the latest model (epoch 39, total_iters 106260)
# saving the model at the end of epoch 39, iters 106275
# End of epoch 39 / 40 	 Time Taken: 273 sec
# (epoch: 39, iters: 2725, time: 0.098, data: 0.002) D_A: 0.229 G_A: 0.271 cycle_A: 0.050 idt_A: 0.009 D_B: 0.232 G_B: 0.265 cycle_B: 0.068 idt_B: 0.014
# learning rate 0.0000065 -> 0.0000000
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106375)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106490)
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106605)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106720)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106835)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 106950)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107065)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107180)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107295)
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107410)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107525)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107640)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107755)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107870)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 107985)
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108100)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108215)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108330)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108445)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108560)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108675)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108790)
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 108905)
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the model at the end of epoch 40, iters 109000
# End of epoch 40 / 40 	 Time Taken: 267 sec
# (epoch: 40, iters: 2725, time: 0.099, data: 0.002) D_A: 0.229 G_A: 0.261 cycle_A: 0.075 idt_A: 0.010 D_B: 0.259 G_B: 0.255 cycle_B: 0.069 idt_B: 0.021

# %%
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer/ --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --num_test size_testA

#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --checkpoints_dir './checkpoints_normV1' --results_dir './results_normV1/' --num_test 388
#CYCLE GAN 30X30
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --checkpoints_dir './checkpoints_normV2' --preprocess 'none' --no_flip --display_winsize 384 --results_dir './results_normV2/' #--num_test 523
#CYCLE GAN 30X30
# !python test.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --checkpoints_dir './checkpoints_normV2_lr_0_0002' --load_size 256 --no_flip --netG unet_256 --display_winsize 384 --results_dir './results_normV2_lr_0_0002/' #--num_test 523
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints_normV2_lr_0_0002	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: ./datasets/DCE_MRI_breastCancer_normV2	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 384                           	[default: 256]
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 2                             	[default: 3]
#                      name: DCEMRI_cyclegan               	[default: experiment_name]
#                       ndf: 64
#                      netD: n_layers                      	[default: basic]
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True
#                   no_flip: True                          	[default: False]
#                      norm: instance
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results_normV2_lr_0_0002/   	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# loading the model from ./checkpoints_normV2_lr_0_0002/DCEMRI_cyclegan/latest_net_G_A.pth
# loading the model from ./checkpoints_normV2_lr_0_0002/DCEMRI_cyclegan/latest_net_G_B.pth
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 54.403 M
# [Network G_B] Total number of parameters : 54.403 M
# -----------------------------------------------
# creating web directory ./results_normV2_lr_0_0002/DCEMRI_cyclegan/test_latest
# processing (0000)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_1.png']
# processing (0001)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_10.png']
# processing (0002)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_11.png']
# processing (0003)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_12.png']
# processing (0004)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_13.png']
# processing (0005)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_14.png']
# processing (0006)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_15.png']
# processing (0007)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_16.png']
# processing (0008)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_17.png']
# processing (0009)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_18.png']
# processing (0010)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_19.png']
# processing (0011)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_2.png']
# processing (0012)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_20.png']
# processing (0013)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_21.png']
# processing (0014)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_22.png']
# processing (0015)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_23.png']
# processing (0016)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_24.png']
# processing (0017)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_25.png']
# processing (0018)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_26.png']
# processing (0019)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_27.png']
# processing (0020)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_28.png']
# processing (0021)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_29.png']
# processing (0022)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_3.png']
# processing (0023)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_30.png']
# processing (0024)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_31.png']
# processing (0025)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_32.png']
# processing (0026)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_33.png']
# processing (0027)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_34.png']
# processing (0028)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_35.png']
# processing (0029)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_36.png']
# processing (0030)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_37.png']
# processing (0031)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_38.png']
# processing (0032)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_39.png']
# processing (0033)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_4.png']
# processing (0034)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_40.png']
# processing (0035)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_41.png']
# processing (0036)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_42.png']
# processing (0037)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_43.png']
# processing (0038)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_44.png']
# processing (0039)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_45.png']
# processing (0040)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_46.png']
# processing (0041)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_47.png']
# processing (0042)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_48.png']
# processing (0043)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_49.png']
# processing (0044)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_5.png']
# processing (0045)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_50.png']
# processing (0046)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_51.png']
# processing (0047)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_52.png']
# processing (0048)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_53.png']
# processing (0049)-th image... ['./datasets/DCE_MRI_breastCancer_normV2/testA/b15_54.png']
