# %%
import os
root="/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo2/pytorch-CycleGAN-and-pix2pix/datasets/DCE_MRI_breastCancer_normV2"
os.chdir(root)

# %%
directory_list=[directory for directory in os.listdir() if not directory.startswith('.')]

# %%
#for image in os.getcwd():

for directory in directory_list:
  directory_path=os.path.join(root, directory)
  os.chdir(directory_path)
  subdirectory_list=[subdirectory for subdirectory in os.listdir() if not subdirectory.startswith('.')]
  for subdirectory in subdirectory_list:
    subdirectory_path=os.path.join(directory_path, subdirectory)
    os.chdir(subdirectory_path)
    # !cp * '../'

# %%
import os
root="/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo3/pytorch-CycleGAN-and-pix2pix/datasets/DCE_MRI_breastCancer_noBM_normV2"
os.chdir(root)

# %%
directory_list=[directory for directory in os.listdir() if not directory.startswith('.')]

# %%
#for image in os.getcwd():

for directory in directory_list:
  directory_path=os.path.join(root, directory)
  os.chdir(directory_path)
  subdirectory_list=[subdirectory for subdirectory in os.listdir() if not subdirectory.startswith('.')]
  for subdirectory in subdirectory_list:
    subdirectory_path=os.path.join(directory_path, subdirectory)
    os.chdir(subdirectory_path)
    # !cp * '../'

# %%
import os
root="/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo4/pytorch-CycleGAN-and-pix2pix/datasets/DCE_MRI_breastCancer_normV2_resized"
os.chdir(root)

# %%
directory_list=[directory for directory in os.listdir() if (directory.endswith("trainA") or directory.endswith("trainB") and not directory.startswith('.'))]
print(directory_list)
# Out:
# ['trainA', 'trainB']

# %%
#for image in os.getcwd():

for directory in directory_list:
  directory_path=os.path.join(root, directory)
  os.chdir(directory_path)
  subdirectory_list=[subdirectory for subdirectory in os.listdir() if not subdirectory.startswith('.')]
  for subdirectory in subdirectory_list:
    subdirectory_path=os.path.join(directory_path, subdirectory)
    os.chdir(subdirectory_path)
    # !cp * '../'

# %%
import os
root="/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo5/pytorch-CycleGAN-and-pix2pix/datasets/DCE_MRI_breastCancer_noBM_normV2_resized"
os.chdir(root)

# %%
directory_list=[directory for directory in os.listdir() if not directory.startswith('.')]

# %%
#for image in os.getcwd():

for directory in directory_list:
  directory_path=os.path.join(root, directory)
  os.chdir(directory_path)
  subdirectory_list=[subdirectory for subdirectory in os.listdir() if not subdirectory.startswith('.')]
  for subdirectory in subdirectory_list:
    subdirectory_path=os.path.join(directory_path, subdirectory)
    os.chdir(subdirectory_path)
    # !cp * '../'
