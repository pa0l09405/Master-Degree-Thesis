# %%
#DA ESEGUIRE 1 SOLA VOLTA !!!!
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo3/") 
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 2337 (delta 0), reused 2 (delta 0), pack-reused 2334
# Receiving objects: 100% (2337/2337), 8.09 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (1497/1497), done.

# %%
# !nvidia-smi
# Out:
# Sun Nov  8 14:55:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo3/pytorch-CycleGAN-and-pix2pix") 
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.7.0+cu101)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.8.1+cu101)
# Collecting dominate>=2.4.0
#   Downloading https://files.pythonhosted.org/packages/ef/a8/4354f8122c39e35516a2708746d89db5e339c867abbd8e0179bccee4b7f9/dominate-2.6.0-py2.py3-none-any.whl
# Collecting visdom>=0.1.8.8
#   Downloading https://files.pythonhosted.org/packages/c9/75/e078f5a2e1df7e0d3044749089fc2823e62d029cc027ed8ae5d71fafcbdc/visdom-0.1.8.9.tar.gz (676kB)
#      |████████████████████████████████| 686kB 4.4MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.4.0->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.5.0->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (19.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.15.0)
# Collecting jsonpatch
#   Downloading https://files.pythonhosted.org/packages/4f/d0/34b0f59ac08de9c1e07876cfecd80aec650600177b4bd445124c755499a7/jsonpatch-1.26-py2.py3-none-any.whl
# Collecting torchfile
#   Downloading https://files.pythonhosted.org/packages/91/af/5b305f86f2d218091af657ddb53f984ecbd9518ca9fe8ef4103a007252c9/torchfile-0.1.0.tar.gz
# Collecting websocket-client
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 50.0MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.8->-r requirements.txt (line 4)) (2.10)
# Collecting jsonpointer>=1.9
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Building wheels for collected packages: visdom, torchfile
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=a1bec196a6fac0d37e3ac6c064dd838e37491011ce70ced8defb81957d52aad6
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=8f6bbcc160ac08e551391ef7b162dd8f65f71a187a10cc14bd514741a57d581a
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# Installing collected packages: dominate, jsonpointer, jsonpatch, torchfile, websocket-client, visdom
# Successfully installed dominate-2.6.0 jsonpatch-1.26 jsonpointer-2.0 torchfile-0.1.0 visdom-0.1.8.9 websocket-client-0.57.0

# %%
"""


A (source domain), B (target domain).
        Generators: G_A: A -> B; G_B: B -> A.
        Discriminators: D_A: G_A(A) vs. B; D_B: G_B(B) vs. A.
        Forward cycle loss:  lambda_A * ||G_B(G_A(A)) - A|| (Eqn. (2) in the paper)
        Backward cycle loss: lambda_B * ||G_A(G_B(B)) - B|| (Eqn. (2) in the paper)
        Identity loss (optional): lambda_identity * (||G_A(B) - B|| * lambda_B + ||G_B(A) - A|| * lambda_A) (Sec 5.2 "Photo generation from paintings" in the paper)
        Dropout is not used in the original CycleGAN paper.




epoch: -- current epoch

iters: -- current training iteration during this epoch (reset to 0 at the end of every epoch) 

time: -- current training iteration during this epoch (reset to 0 at the end of every epoch)

data: -- data loading time per data point (normalized by batch_size) 

D_A: GAN loss for discriminator D_A
G_A: loss for generators G_A 
cycle_A: cycle-consistency loss A 
idt_A: identity loss B 

D_B: GAN loss for discriminator D_B 
G_B: loss for generators G_B 
cycle_B: cycle-consistency loss B 
idt_B: identity loss B






# #epoche
# #epochs_decay
#dataroot
#input_nc
#output_nc
#norm
#no_dropout 
#dataset_mode
#direction
#batch size (adesso è 1!)
#load_size
#crop_size
#preprocess
# save_latest_freq default 5000
# save_epoch_freq default 5
"""
import os
os.chdir("/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo3/pytorch-CycleGAN-and-pix2pix")
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 13 --lr 0.002
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002


#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 8 --lr 0.002 --checkpoints_dir './checkpoints_normV1'
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002 --checkpoints_dir './checkpoints_normV1'

#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 1 --lr 0.002 --checkpoints_dir './checkpoints_normV2'
#CYCLEGAN 30X30
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --preprocess 'none' --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 4 --n_epochs_decay 11 --lr 0.002 --checkpoints_dir './checkpoints_noBM_normV2'
#CYCLEGAN 70X70
# !python train.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2 --batch_size 4 --name DCEMRI_cyclegan --load_size 256 --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --netG unet_256 --input_nc 1 --netD n_layers --n_layers_D 2 --output_nc 1 --n_epochs 10 --n_epochs_decay 30 --lr 0.0002 --checkpoints_dir './checkpoints_noBM_normV2_lr_0_0002'
# Out:
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints_noBM_normV2_lr_0_0002	[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/DCE_MRI_breastCancer_noBM_normV2	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 384                           	[default: 256]
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256                           	[default: 286]
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: cycle_gan
#                  n_epochs: 10                            	[default: 100]
#            n_epochs_decay: 30                            	[default: 100]
#                n_layers_D: 2                             	[default: 3]
#                      name: DCEMRI_cyclegan               	[default: experiment_name]
#                       ndf: 64
#                      netD: n_layers                      	[default: basic]
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True
#                   no_flip: True                          	[default: False]
#                   no_html: False
#                      norm: instance
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# The number of training images = 3712
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 54.403 M
# [Network G_B] Total number of parameters : 54.403 M
# [Network D_A] Total number of parameters : 0.661 M
# [Network D_B] Total number of parameters : 0.661 M
# -----------------------------------------------
# create web directory ./checkpoints_noBM_normV2_lr_0_0002/DCEMRI_cyclegan/web...
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# learning rate 0.0002000 -> 0.0002000
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# [epoch : 1 ] ---> learning rate= 0.0002
#
# End of epoch 1 / 40 	 Time Taken: 1016 sec
# (epoch: 1, iters: 3712, time: 0.061, data: 0.000) D_A: 0.252 G_A: 0.273 cycle_A: 0.250 idt_A: 0.074 D_B: 0.234 G_B: 0.278 cycle_B: 0.205 idt_B: 0.101
# learning rate 0.0002000 -> 0.0002000
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 2, total_iters 5000)
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# [epoch : 2 ] ---> learning rate= 0.0002
#
# End of epoch 2 / 40 	 Time Taken: 198 sec
# (epoch: 2, iters: 3712, time: 0.062, data: 0.000) D_A: 0.221 G_A: 0.293 cycle_A: 0.252 idt_A: 0.500 D_B: 0.229 G_B: 0.280 cycle_B: 0.291 idt_B: 0.074
# learning rate 0.0002000 -> 0.0002000
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 3, total_iters 10000)
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# [epoch : 3 ] ---> learning rate= 0.0002
#
# End of epoch 3 / 40 	 Time Taken: 187 sec
# (epoch: 3, iters: 3712, time: 0.062, data: 0.002) D_A: 0.277 G_A: 0.235 cycle_A: 0.133 idt_A: 0.045 D_B: 0.275 G_B: 0.255 cycle_B: 0.111 idt_B: 0.046
# learning rate 0.0002000 -> 0.0002000
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# [epoch : 4 ] ---> learning rate= 0.0002
#
# End of epoch 4 / 40 	 Time Taken: 184 sec
# (epoch: 4, iters: 3712, time: 0.061, data: 0.002) D_A: 0.251 G_A: 0.393 cycle_A: 0.157 idt_A: 0.044 D_B: 0.225 G_B: 0.253 cycle_B: 0.133 idt_B: 0.075
# learning rate 0.0002000 -> 0.0002000
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 5, total_iters 15000)
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# [epoch : 5 ] ---> learning rate= 0.0002
#
# saving the model at the end of epoch 5, iters 18560
# End of epoch 5 / 40 	 Time Taken: 191 sec
# (epoch: 5, iters: 3712, time: 0.061, data: 0.002) D_A: 0.254 G_A: 0.258 cycle_A: 0.145 idt_A: 0.034 D_B: 0.253 G_B: 0.257 cycle_B: 0.101 idt_B: 0.056
# learning rate 0.0002000 -> 0.0002000
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 6, total_iters 20000)
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# [epoch : 6 ] ---> learning rate= 0.0002
#
# End of epoch 6 / 40 	 Time Taken: 187 sec
# (epoch: 6, iters: 3712, time: 0.061, data: 0.002) D_A: 0.243 G_A: 0.245 cycle_A: 0.122 idt_A: 0.027 D_B: 0.254 G_B: 0.350 cycle_B: 0.100 idt_B: 0.045
# learning rate 0.0002000 -> 0.0002000
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 7, total_iters 25000)
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# [epoch : 7 ] ---> learning rate= 0.0002
#
# End of epoch 7 / 40 	 Time Taken: 186 sec
# (epoch: 7, iters: 3712, time: 0.061, data: 0.002) D_A: 0.222 G_A: 0.325 cycle_A: 0.160 idt_A: 0.066 D_B: 0.222 G_B: 0.287 cycle_B: 0.208 idt_B: 0.053
# learning rate 0.0002000 -> 0.0002000
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# [epoch : 8 ] ---> learning rate= 0.0002
#
# End of epoch 8 / 40 	 Time Taken: 184 sec
# (epoch: 8, iters: 3712, time: 0.061, data: 0.002) D_A: 0.213 G_A: 0.412 cycle_A: 0.177 idt_A: 0.032 D_B: 0.198 G_B: 0.191 cycle_B: 0.085 idt_B: 0.050
# learning rate 0.0002000 -> 0.0002000
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# saving the latest model (epoch 9, total_iters 30000)
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# [epoch : 9 ] ---> learning rate= 0.0002
#
# End of epoch 9 / 40 	 Time Taken: 186 sec
# (epoch: 9, iters: 3712, time: 0.061, data: 0.002) D_A: 0.240 G_A: 0.191 cycle_A: 0.150 idt_A: 0.040 D_B: 0.248 G_B: 0.299 cycle_B: 0.140 idt_B: 0.046
# learning rate 0.0002000 -> 0.0001935
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the latest model (epoch 10, total_iters 35000)
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# [epoch : 10 ] ---> learning rate= 0.00019354838709677422
#
# saving the model at the end of epoch 10, iters 37120
# End of epoch 10 / 40 	 Time Taken: 191 sec
# (epoch: 10, iters: 3712, time: 0.061, data: 0.002) D_A: 0.221 G_A: 0.261 cycle_A: 0.117 idt_A: 0.029 D_B: 0.235 G_B: 0.276 cycle_B: 0.106 idt_B: 0.037
# learning rate 0.0001935 -> 0.0001871
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# saving the latest model (epoch 11, total_iters 40000)
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# [epoch : 11 ] ---> learning rate= 0.00018709677419354842
#
# End of epoch 11 / 40 	 Time Taken: 186 sec
# (epoch: 11, iters: 3712, time: 0.061, data: 0.002) D_A: 0.216 G_A: 0.250 cycle_A: 0.117 idt_A: 0.031 D_B: 0.219 G_B: 0.275 cycle_B: 0.110 idt_B: 0.035
# learning rate 0.0001871 -> 0.0001806
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# [epoch : 12 ] ---> learning rate= 0.00018064516129032257
#
# End of epoch 12 / 40 	 Time Taken: 184 sec
# (epoch: 12, iters: 3712, time: 0.061, data: 0.001) D_A: 0.219 G_A: 0.311 cycle_A: 0.122 idt_A: 0.026 D_B: 0.241 G_B: 0.344 cycle_B: 0.091 idt_B: 0.037
# learning rate 0.0001806 -> 0.0001742
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# saving the latest model (epoch 13, total_iters 45000)
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# [epoch : 13 ] ---> learning rate= 0.00017419354838709678
#
# End of epoch 13 / 40 	 Time Taken: 186 sec
# (epoch: 13, iters: 3712, time: 0.061, data: 0.002) D_A: 0.194 G_A: 0.238 cycle_A: 0.132 idt_A: 0.027 D_B: 0.248 G_B: 0.225 cycle_B: 0.109 idt_B: 0.038
# learning rate 0.0001742 -> 0.0001677
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# saving the latest model (epoch 14, total_iters 50000)
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# [epoch : 14 ] ---> learning rate= 0.00016774193548387098
#
# End of epoch 14 / 40 	 Time Taken: 186 sec
# (epoch: 14, iters: 3712, time: 0.061, data: 0.002) D_A: 0.219 G_A: 0.232 cycle_A: 0.148 idt_A: 0.028 D_B: 0.247 G_B: 0.301 cycle_B: 0.099 idt_B: 0.037
# learning rate 0.0001677 -> 0.0001613
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the latest model (epoch 15, total_iters 55000)
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# [epoch : 15 ] ---> learning rate= 0.00016129032258064516
#
# saving the model at the end of epoch 15, iters 55680
# End of epoch 15 / 40 	 Time Taken: 190 sec
# (epoch: 15, iters: 3712, time: 0.061, data: 0.002) D_A: 0.237 G_A: 0.270 cycle_A: 0.128 idt_A: 0.023 D_B: 0.230 G_B: 0.275 cycle_B: 0.081 idt_B: 0.035
# learning rate 0.0001613 -> 0.0001548
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# [epoch : 16 ] ---> learning rate= 0.00015483870967741937
#
# End of epoch 16 / 40 	 Time Taken: 184 sec
# (epoch: 16, iters: 3712, time: 0.061, data: 0.001) D_A: 0.239 G_A: 0.272 cycle_A: 0.135 idt_A: 0.039 D_B: 0.251 G_B: 0.252 cycle_B: 0.137 idt_B: 0.036
# learning rate 0.0001548 -> 0.0001484
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# saving the latest model (epoch 17, total_iters 60000)
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# [epoch : 17 ] ---> learning rate= 0.00014838709677419355
#
# End of epoch 17 / 40 	 Time Taken: 186 sec
# (epoch: 17, iters: 3712, time: 0.061, data: 0.002) D_A: 0.276 G_A: 0.157 cycle_A: 0.158 idt_A: 0.037 D_B: 0.241 G_B: 0.280 cycle_B: 0.154 idt_B: 0.045
# learning rate 0.0001484 -> 0.0001419
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# saving the latest model (epoch 18, total_iters 65000)
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# [epoch : 18 ] ---> learning rate= 0.00014193548387096775
#
# End of epoch 18 / 40 	 Time Taken: 186 sec
# (epoch: 18, iters: 3712, time: 0.061, data: 0.001) D_A: 0.261 G_A: 0.379 cycle_A: 0.113 idt_A: 0.023 D_B: 0.238 G_B: 0.247 cycle_B: 0.081 idt_B: 0.030
# learning rate 0.0001419 -> 0.0001355
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# saving the latest model (epoch 19, total_iters 70000)
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# [epoch : 19 ] ---> learning rate= 0.00013548387096774196
#
# End of epoch 19 / 40 	 Time Taken: 186 sec
# (epoch: 19, iters: 3712, time: 0.061, data: 0.001) D_A: 0.227 G_A: 0.241 cycle_A: 0.112 idt_A: 0.026 D_B: 0.252 G_B: 0.236 cycle_B: 0.082 idt_B: 0.028
# learning rate 0.0001355 -> 0.0001290
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# [epoch : 20 ] ---> learning rate= 0.00012903225806451613
#
# saving the model at the end of epoch 20, iters 74240
# End of epoch 20 / 40 	 Time Taken: 188 sec
# (epoch: 20, iters: 3712, time: 0.061, data: 0.002) D_A: 0.241 G_A: 0.112 cycle_A: 0.096 idt_A: 0.019 D_B: 0.245 G_B: 0.249 cycle_B: 0.064 idt_B: 0.026
# learning rate 0.0001290 -> 0.0001226
# [epoch : 21 ] ---> learning rate= 0.00012258064516129034
#
# ...
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# saving the latest model (epoch 34, total_iters 125000)
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# [epoch : 34 ] ---> learning rate= 3.870967741935485e-05
#
# End of epoch 34 / 40 	 Time Taken: 187 sec
# (epoch: 34, iters: 3712, time: 0.061, data: 0.002) D_A: 0.234 G_A: 0.235 cycle_A: 0.101 idt_A: 0.020 D_B: 0.255 G_B: 0.284 cycle_B: 0.075 idt_B: 0.023
# learning rate 0.0000387 -> 0.0000323
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# [epoch : 35 ] ---> learning rate= 3.225806451612903e-05
#
# saving the model at the end of epoch 35, iters 129920
# End of epoch 35 / 40 	 Time Taken: 188 sec
# (epoch: 35, iters: 3712, time: 0.061, data: 0.002) D_A: 0.260 G_A: 0.237 cycle_A: 0.122 idt_A: 0.018 D_B: 0.254 G_B: 0.268 cycle_B: 0.064 idt_B: 0.025
# learning rate 0.0000323 -> 0.0000258
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# saving the latest model (epoch 36, total_iters 130000)
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# [epoch : 36 ] ---> learning rate= 2.5806451612903226e-05
#
# End of epoch 36 / 40 	 Time Taken: 186 sec
# (epoch: 36, iters: 3712, time: 0.061, data: 0.001) D_A: 0.245 G_A: 0.276 cycle_A: 0.096 idt_A: 0.019 D_B: 0.244 G_B: 0.263 cycle_B: 0.050 idt_B: 0.020
# learning rate 0.0000258 -> 0.0000194
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# saving the latest model (epoch 37, total_iters 135000)
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# [epoch : 37 ] ---> learning rate= 1.9354838709677424e-05
#
# End of epoch 37 / 40 	 Time Taken: 186 sec
# (epoch: 37, iters: 3712, time: 0.061, data: 0.002) D_A: 0.243 G_A: 0.280 cycle_A: 0.112 idt_A: 0.015 D_B: 0.239 G_B: 0.241 cycle_B: 0.051 idt_B: 0.024
# learning rate 0.0000194 -> 0.0000129
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# saving the latest model (epoch 38, total_iters 140000)
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# [epoch : 38 ] ---> learning rate= 1.2903225806451625e-05
#
# End of epoch 38 / 40 	 Time Taken: 187 sec
# (epoch: 38, iters: 3712, time: 0.061, data: 0.002) D_A: 0.230 G_A: 0.269 cycle_A: 0.095 idt_A: 0.018 D_B: 0.246 G_B: 0.264 cycle_B: 0.070 idt_B: 0.019
# learning rate 0.0000129 -> 0.0000065
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# [epoch : 39 ] ---> learning rate= 6.451612903225801e-06
#
# End of epoch 39 / 40 	 Time Taken: 184 sec
# (epoch: 39, iters: 3712, time: 0.061, data: 0.002) D_A: 0.241 G_A: 0.253 cycle_A: 0.105 idt_A: 0.017 D_B: 0.243 G_B: 0.264 cycle_B: 0.065 idt_B: 0.021
# learning rate 0.0000065 -> 0.0000000
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the latest model (epoch 40, total_iters 145000)
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# [epoch : 40 ] ---> learning rate= 0.0
#
# saving the model at the end of epoch 40, iters 148480
# End of epoch 40 / 40 	 Time Taken: 190 sec
# (epoch: 40, iters: 3712, time: 0.061, data: 0.002) D_A: 0.241 G_A: 0.256 cycle_A: 0.085 idt_A: 0.017 D_B: 0.242 G_B: 0.269 cycle_B: 0.061 idt_B: 0.018

# %%
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer/ --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --num_test size_testA

#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --checkpoints_dir './checkpoints_normV1' --results_dir './results_normV1/' --num_test 388
#CYCLEGAN 30X30
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --checkpoints_dir './checkpoints_noBM_normV2' --preprocess 'none' --no_flip --display_winsize 384 --results_dir './results_noBM_normV2/' #--num_test 523
#CYCLEGAN 70X70
# !python test.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2  --netD n_layers --n_layers_D 2 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --checkpoints_dir './checkpoints_noBM_normV2_lr_0_0002' --load_size 256 --no_flip --netG unet_256 --display_winsize 384 --results_dir './results_noBM_normV2_lr_0_0002/' #--num_test 523
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints_noBM_normV2_lr_0_0002	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: ./datasets/DCE_MRI_breastCancer_noBM_normV2	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 384                           	[default: 256]
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 2                             	[default: 3]
#                      name: DCEMRI_cyclegan               	[default: experiment_name]
#                       ndf: 64
#                      netD: n_layers                      	[default: basic]
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True
#                   no_flip: True                          	[default: False]
#                      norm: instance
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 1                             	[default: 3]
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results_noBM_normV2_lr_0_0002/	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# loading the model from ./checkpoints_noBM_normV2_lr_0_0002/DCEMRI_cyclegan/latest_net_G_A.pth
# loading the model from ./checkpoints_noBM_normV2_lr_0_0002/DCEMRI_cyclegan/latest_net_G_B.pth
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 54.403 M
# [Network G_B] Total number of parameters : 54.403 M
# -----------------------------------------------
# creating web directory ./results_noBM_normV2_lr_0_0002/DCEMRI_cyclegan/test_latest
# processing (0000)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_1.png']
# processing (0001)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_10.png']
# processing (0002)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_100.png']
# processing (0003)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_101.png']
# processing (0004)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_102.png']
# processing (0005)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_103.png']
# processing (0006)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_104.png']
# processing (0007)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_105.png']
# processing (0008)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_106.png']
# processing (0009)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_107.png']
# processing (0010)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_108.png']
# processing (0011)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_109.png']
# processing (0012)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_11.png']
# processing (0013)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_110.png']
# processing (0014)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_111.png']
# processing (0015)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_112.png']
# processing (0016)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_113.png']
# processing (0017)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_114.png']
# processing (0018)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_115.png']
# processing (0019)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_116.png']
# processing (0020)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_117.png']
# processing (0021)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_118.png']
# processing (0022)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_119.png']
# processing (0023)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_12.png']
# processing (0024)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_120.png']
# processing (0025)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_121.png']
# processing (0026)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_122.png']
# processing (0027)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_123.png']
# processing (0028)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_124.png']
# processing (0029)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_125.png']
# processing (0030)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_126.png']
# processing (0031)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_127.png']
# processing (0032)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_128.png']
# processing (0033)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_13.png']
# processing (0034)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_14.png']
# processing (0035)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_15.png']
# processing (0036)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_16.png']
# processing (0037)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_17.png']
# processing (0038)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_18.png']
# processing (0039)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_19.png']
# processing (0040)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_2.png']
# processing (0041)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_20.png']
# processing (0042)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_21.png']
# processing (0043)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_22.png']
# processing (0044)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_23.png']
# processing (0045)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_24.png']
# processing (0046)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_25.png']
# processing (0047)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_26.png']
# processing (0048)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_27.png']
# processing (0049)-th image... ['./datasets/DCE_MRI_breastCancer_noBM_normV2/testA/b85_28.png']
