# %%
#DA ESEGUIRE 1 SOLA VOLTA !!!!
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo5/") 
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
# !nvidia-smi
# Out:
# Fri Dec  4 17:57:46 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# ...

# %%
import os
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo5/pytorch-CycleGAN-and-pix2pix") 
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 6.2MB/s
# ...
#      |████████████████████████████████| 204kB 14.6MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=cd8cc88da739c94a80f758d4d7c074873434b85a7d8d9b90b71a85885332749c
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=702b93c30ff8b24b8797d86020debdc8c9e5eb6169505011b738bed9a042e6df
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
"""


A (source domain), B (target domain).
        Generators: G_A: A -> B; G_B: B -> A.
        Discriminators: D_A: G_A(A) vs. B; D_B: G_B(B) vs. A.
        Forward cycle loss:  lambda_A * ||G_B(G_A(A)) - A|| (Eqn. (2) in the paper)
        Backward cycle loss: lambda_B * ||G_A(G_B(B)) - B|| (Eqn. (2) in the paper)
        Identity loss (optional): lambda_identity * (||G_A(B) - B|| * lambda_B + ||G_B(A) - A|| * lambda_A) (Sec 5.2 "Photo generation from paintings" in the paper)
        Dropout is not used in the original CycleGAN paper.




epoch: -- current epoch

iters: -- current training iteration during this epoch (reset to 0 at the end of every epoch) 

time: -- current training iteration during this epoch (reset to 0 at the end of every epoch)

data: -- data loading time per data point (normalized by batch_size) 

D_A: GAN loss for discriminator D_A
G_A: loss for generators G_A 
cycle_A: cycle-consistency loss A 
idt_A: identity loss B 

D_B: GAN loss for discriminator D_B 
G_B: loss for generators G_B 
cycle_B: cycle-consistency loss B 
idt_B: identity loss B






# #epoche
# #epochs_decay
#dataroot
#input_nc
#output_nc
#norm
#no_dropout 
#dataset_mode
#direction
#batch size (adesso è 1!)
#load_size
#crop_size
#preprocess
# save_latest_freq default 5000
# save_epoch_freq default 5
"""
import os
os.chdir("/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo5/pytorch-CycleGAN-and-pix2pix")
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 13 --lr 0.002
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002


#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 8 --lr 0.002 --checkpoints_dir './checkpoints_normV1'
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --dataset_mode dceMri --input_nc 1 --output_nc 1 --n_epochs 1 --n_epochs_decay 14 --direction BtoA --lr 0.002 --checkpoints_dir './checkpoints_normV1'

#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_normV2 --batch_size 1 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 1 --lr 0.002 --checkpoints_dir './checkpoints_normV2'
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --save_epoch_freq 5 --batch_size 4 --name DCEMRI_cyclegan --load_size 256 --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 10 --n_epochs_decay 0 --lr 0.0002 --checkpoints_dir './checkpoints_noBM_normV2_resized_27_11_2020'
#!python train.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --batch_size 4 --name DCEMRI_cyclegan --netD n_layers --n_layers_D 2 --load_size 256 --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --netG unet_256 --input_nc 1 --output_nc 1 --n_epochs 10 --n_epochs_decay 40 --lr 0.0002 --checkpoints_dir './checkpoints_noBM_normV2_resized_lr_0_0002'
# !python train.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --netG unet_256 --save_epoch_freq 1 --batch_size 1 --name DCEMRI_cyclegan --load_size 256 --no_flip --display_id 0 --display_winsize 384 --model cycle_gan --input_nc 1 --output_nc 1 --n_epochs 2 --n_epochs_decay 0 --lr 0.0002 --checkpoints_dir './checkpoints_noBM_normV2_resized_1_12_2020_unet256'

# %%
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer/ --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --num_test size_testA

#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_normV1 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --dataset_mode dceMri --checkpoints_dir './checkpoints_normV1' --results_dir './results_normV1/' --num_test 388

#!python test.py --phase valid --eval --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --checkpoints_dir './checkpoints_noBM_normV2_resized_27_11_2020' --no_flip --load_size 256 --display_winsize 384 --results_dir './results_noBM_normV2_resized__27_11_2020/'
#!python test.py --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --netD n_layers --n_layers_D 2 --checkpoints_dir './checkpoints_noBM_normV2_resized_lr_0_0002' --load_size 256 --no_flip --display_winsize 384 --netG unet_256 --results_dir './results_noBM_normV2_resized_lr_0_0002/'
#python test.py --phase valid --eval --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --checkpoints_dir './checkpoints_noBM_normV2_resized_28_11_2020_BtoA' --no_flip --load_size 256 --display_winsize 384 --results_dir './results_noBM_normV2_resized__28_11_2020_BtoA/'

#FINAL TEST PHASE for unet
#!python test.py --eval --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --netG unet_256 --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --checkpoints_dir './checkpoints_noBM_normV2_resized_finalTrain_unet256_40epoche' --no_flip --load_size 256 --display_winsize 384 --results_dir './results_normV2_resized_finalTrain_unet256_40epoche/'

#FINAL TEST PHASE for resnet
# !python test.py --eval --dataroot ./datasets/DCE_MRI_breastCancer_noBM_normV2_resized --input_nc 1 --output_nc 1 --name DCEMRI_cyclegan --model cycle_gan --checkpoints_dir './checkpoints_noBM_normV2_resized_finalTrain_resnet_10epoche' --no_flip --load_size 256 --display_winsize 384 --results_dir './results_normV2_resized_finalTrain_resnet_10epoche/'

# %%
import os
# !sudo apt-get install bc
os.chdir(r"/content/drive/My Drive/TesiUNINA/Colab Notebooks/tentativo5/pytorch-CycleGAN-and-pix2pix") 

#!bash ./run.sh
# !bash ./finalTrain_run.sh
